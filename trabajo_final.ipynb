# %% [markdown]
# <a href="https://colab.research.google.com/gist/Andrea2812/4ef16f5350f05d40c930550b72c32bad/trabajo_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pymongo import MongoClient

# %%
import pymongo

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
datos_df = pd.read_csv("Armas.csv")

# %%
df = pd.DataFrame (datos)

# %%
import numpy as pd
import time
plt.ticklabel_format(style='plain')
plt.savefig('Barras.png')
df.groupby('PROVINCIA')['CANTIDAD'].sum().plot(kind='bar',legend='reverse',color={'red','yellow','blue','green'})
plt.ylabel("Cantidades")
plt.xlabel("Provincias")
plt.title("Decomiso por provincias : " + str(time.localtime().tm_year ) + "/"+ str(time.localtime().tm_mon,) + "/"+ str(time.localtime().tm_mday))
#Permite visualizar la provincia de mayor decomiso de armas.
# Out:
# Text(0.5, 1.0, 'Decomiso por provincias : 2021/8/27')

# %%
import numpy as pd
import time
plt.ticklabel_format(style='plain')
plt.savefig('Barrasprovincias.png')
plt.figure(figsize=(30,10)) 
df.groupby('CANTÓN')['CANTIDAD'].sum().plot(kind='bar',legend='reverse',color={'red','blue','red','orange'})
plt.ylabel("Cantones")
plt.xlabel("Cantidades")
plt.title("Decomisadas por cantones : " + str(time.localtime().tm_year ) + "/"+ str(time.localtime().tm_mon,) + "/"+ str(time.localtime().tm_mday))
#Permite visualizar el cantón donde existe la mayor cantidad de decomisos de armas.
# Out:
# Text(0.5, 1.0, 'Decomisadas por cantones : 2021/8/27')

# %%
df.head()
# Out:
#                                                FECHA  ... Unnamed: 12
# 0  07/22/2020,Esmeraldas,Eloy Alfaro,,FF.AA,"BIMO...  ...         NaN
# 1  07/22/2020,Esmeraldas,Eloy Alfaro,,FF.AA,"BIMO...  ...         NaN
# 2  07/28/2020,Sucumbíos,Lago Agrio,,FF.AA,"GFE 53...  ...         NaN
# 3  07/28/2020,Sucumbíos,Lago Agrio,,FF.AA,"GFE 53...  ...         NaN
# 4  07/28/2020,Sucumbíos,Lago Agrio,,FF.AA,"GFE 53...  ...         NaN
#
# [5 rows x 13 columns]

# %%
datos_df.to_dict()
# Out:
# {'CALIBRE': {0: nan,
#   1: nan,
#   2: nan,
#   3: nan,
#   4: nan,
#   5: nan,
#   6: nan,
#   7: nan,
#   8: nan,
#   9: nan,
#   10: nan,
#   11: nan,
#   12: nan,
#   13: nan,
#   14: nan,
#   15: nan,
#   16: nan,
#   17: nan,
#   18: nan,
#   19: nan,
#   20: nan,
#   21: nan,
#   22: nan,
#   23: nan,
#   24: nan,
#   25: nan,
#   26: nan,
#   27: nan,
#   28: nan,
#   29: nan,
#   30: nan,
#   31: nan,
#   32: nan,
#   33: nan,
#   34: nan,
#   35: nan,
#   36: nan,
#   37: nan,
#   38: nan,
#   39: nan,
#   40: nan,
#   41: nan,
#   42: nan,
#   43: nan,
#   44: nan,
#   45: nan,
#   46: nan,
#   47: nan,
#   48: nan,
#   49: nan,
#   50: nan,
#   51: nan,
#   52: nan,
#   53: nan,
#   54: nan,
#   55: nan,
#   56: nan,
#   57: nan,
#   58: nan,
#   59: nan,
#   60: nan,
#   61: nan,
#   62: nan,
#   63: nan,
#   64: nan,
#   65: nan,
#   66: nan,
#   67: nan,
#   68: nan,
#   69: nan,
#   70: nan,
#   71: nan,
#   72: nan,
#   73: nan,
#   74: nan,
#   75: nan,
# ...

# %%
provincias=datos['PROVINCIA']

# %%
provincias
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 4305       NaN
# 4306       NaN
# 4307       NaN
# 4308    Guayas
# 4309    Guayas
# Name: PROVINCIA, Length: 4310, dtype: object

# %%
cantones=datos ['CANTÓN']

# %%
cantones
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 4305          NaN
# 4306          NaN
# 4307          NaN
# 4308    Guayaquil
# 4309    Guayaquil
# Name: CANTÓN, Length: 4310, dtype: object

# %%
cantidades=datos ['CANTIDAD']

# %%
cantidades
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 4305     NaN
# 4306     NaN
# 4307     NaN
# 4308     1.0
# 4309    10.0
# Name: CANTIDAD, Length: 4310, dtype: float64

# %%
tipos=datos ['TIPO']

# %%
tipos
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 4305         NaN
# 4306         NaN
# 4307         NaN
# 4308     pistola
# 4309    munición
# Name: TIPO, Length: 4310, dtype: object

# %%
fechas=datos ['FECHA']

# %%
fechas
# Out:
# 0       07/22/2020,Esmeraldas,Eloy Alfaro,,FF.AA,"BIMO...
# 1       07/22/2020,Esmeraldas,Eloy Alfaro,,FF.AA,"BIMO...
# 2       07/28/2020,Sucumbíos,Lago Agrio,,FF.AA,"GFE 53...
# 3       07/28/2020,Sucumbíos,Lago Agrio,,FF.AA,"GFE 53...
# 4       07/28/2020,Sucumbíos,Lago Agrio,,FF.AA,"GFE 53...
#                               ...
# 4305    08/24/2021,Guayas,Guayaquil,",",P.N,,1,fusil,5...
# 4306    08/24/2021,Guayas,Guayaquil,Centro de Privació...
# 4307    08/24/2021,Guayas,Guayaquil,Centro de Privació...
# 4308                                           08/24/2021
# 4309                                           08/24/2021
# Name: FECHA, Length: 4310, dtype: object

# %%
plt.ticklabel_format(style='plain')
plt.figure(figsize=(10,10)) 

df.CANTIDAD.groupby(df.TIPO).sum().plot(kind='pie',cmap='Paired')
plt.axis("equal")
plt.ylabel("")
plt.suptitle('Cantidad de Armas, Munición y explosivos decomisados en Ecuador.')
# Out:
# Text(0.5, 0.98, 'Cantidad de Armas, Munición y explosivos decomisados en Ecuador.')

# %%
datos.dtypes
# Out:
# FECHA                     object
# PROVINCIA                 object
# CANTÓN                    object
# SECTOR                    object
# INSTITUCIÓN               object
# UNIDAD                    object
# CANTIDAD                 float64
# TIPO                      object
# CALIBRE                   object
# DETENIDOS                float64
# DETENIDOS EXTRANJEROS    float64
# MODALIDAD                 object
# Unnamed: 12               object
# dtype: object

# %%
import numpy as np

# %%
import plotly.express as px
import matplotlib.pyplot as plt
plt.figure(figsize=(30,10)) 
plt.savefig('Detenidosporprovincia.png')


fig = px.pie(df, values='DETENIDOS', names='PROVINCIA', title='Detenidos por provincias')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c1cedbb7-16b7-442e-9ea3-8b2f270b451e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1cedbb7-16b7-442e-9ea3-8b2f270b451e")) {
#                     Plotly.newPlot(
#                         'c1cedbb7-16b7-442e-9ea3-8b2f270b451e',
# ...

# %%
resumen=df.groupby(["PROVINCIA","TIPO"]).sum('DETENIDOS').sort_values(by=['TIPO','DETENIDOS'], ascending=False)

resumen
# Out:
#                                    CANTIDAD  DETENIDOS  DETENIDOS EXTRANJEROS
# PROVINCIA       TIPO
# Guayas          volcanes              380.0        0.0                    0.0
# Manabí          uniforme militar        1.0        0.0                    0.0
# El Oro          tubo cañón              1.0        0.0                    0.0
# Loja            tacos dinamita        799.0        8.0                    0.0
# Imbabura        tacos dinamita         85.0        1.0                    0.0
# ...                                     ...        ...                    ...
# Bolívar         Cápsula ordinaria     500.0        0.0                    0.0
# Guayas          Cápsula ordinaria      10.0        0.0                    0.0
# Morona Santiago Cápsula ordinaria      30.0        0.0                    0.0
# Sucumbíos       Cápsula ordinaria     150.0        0.0                    0.0
# Guayas           fusil                  1.0        5.0                    0.0
#
# ...
